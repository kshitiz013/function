# %%
# Q.What is the difference between a function and a method in Python?

# function is line of code which we write to perform a specific task .We write a function so that we don't have to write the code for a specific task again and again

# %%
def add(a,b):
    return a+b
#now we can add any two number with the hellp of this function .

#now we can call this function with any ntwo number .so it saves our times as well as our program is also clean

add(2,3), add(5,6)
# Out:
# (5, 11)

# %%
# Method is also a type of function which is predefined in the class

# %%
#suppose we have a  instance of string which belong to string class and in that class there is a method called upper which convert the lowercase letter to uppercase

a="pwskills"
a.upper()
# Out:
# 'PWSKILLS'

# %%
# Q.Explain the concept of function arguments and parameters in Python?

# %%
def sq(a):
   return a**2
    
sq(10)

"""
Here we se it is an  function which squares a number pass to it .Here a is parameter passed and when the function is called with 10 that 10 is the arguments
"""
# Out:
# '\nHere we se it is an  function which squares a number pass to it .Here a is parameter passed and when the function is called with 10 that 10 is the arguments\n'

# %%
# <!-- Q. What are the different ways to define and call a function in Python?

# First we can define a function using normal def ketword and second is the inline lambda function.

# we can call a function using the function name outside the function as well as inside the function ,this method is known as recursion 
#  -->

# %%
def add(a,b):
    return a+b
add(1,2)
# Out:
# 3

# %%
# Q.What is the purpose of the `return` statement in a Python function?

# Return function return the value  whatever the value  the function has calculated or anything back to the caller,so wherever the function is called it will get that value

# %%
def upper_case(a):
    return a.upper()

upper_case("pwskills")
# Out:
# 'PWSKILLS'

# %%
# <!-- Q.What are iterators in Python and how do they differ from iterables?

# Iterable are those data structure or data type whose each part can be accessed one by one or when we pass a loop throgh that thing we can get each element or its each 
# part
#  -->

# %%
a=[1,2,3,4,5]

for i in a:
    print(i)
    
#here a is list which is iterale and we can access its each element
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Iterator  Iterator is an object that allows traversal through a countable number of values. It is used to iterate over iterable objects like lists, tuples, sets, etc

# %%
# Q.. Explain the concept of generators in Python and how they are defined.

# Generators are a simple way to create iterators using functions and the yield keyword instead of returning values.

# %%
# Generators return data in an iterable format, allowing the sequence to be iterated over, much like a list or tuple.

# %%
# Q. What are the advantages of using generators over regular functions?

# These generators do not store every element in the memory.
# On-Demand Data: Generators produce values one at a time and only when required, avoiding the need to generate or store all values upfront.
# Memory Efficiency: Since values are generated as needed and not all at once, generators use minimal memory.

# %%
 # Q..What is a lambda function in Python and when is it typically used?

# %%
# lambda function are one liner functions it is usually used as the callback function to iterate over the iterator and return new list of value

# %%
# Q. Explain the purpose and usage of the `map()` function in Python

# %%
# map function is used when we want to iterate over a list of values and after performing some specific operation we return a new sets of values

# %%
# Q.. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?

# %%
# map--map function is used when we want to iterate over a list of values and after performing some specific operation we return
# a new sets of values

# reduce-- reduce is used when we want to return a single value by iterating  over a list of element.List take two numbers at a time 
# and after performing some operation it merges both number and then take the third number and perform opration on this and 
# the number which we got by performing the operation between two number likwiae this goes on and we get a single number

# filter--it filter the list based on some specific conditions

# %%
# Q..Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];

# %% [markdown]
# ![WhatsApp Image 2024-07-30 at 10.59.35_f6d072f0.jpg](attachment:baebf05a-79bb-4ea2-9675-7ef13c789c56.jpg)
